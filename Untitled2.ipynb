# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.155 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.1/107.7 GB disk)

# %%
import cv2

import random
from ultralytics import YOLO

# Read class names from the file
with open(r'/content/cock.txt', 'r') as my_file:
    class_list = my_file.read().split('\n')

# Generate random colors for each class
detection_color = []
for _ in range(len(class_list)):
    r = random.randint(0, 255)
    g = random.randint(0, 255)
    b = random.randint(0, 255)
    detection_color.append((r, g, b))

# Load YOLOv8 model (downloads if not present)
model = YOLO('yolov8n.pt')
cap = cv2.VideoCapture(r'/content/SampleVideo_1280x720_1mb.mp4')
if not cap.isOpened():
  print("We cannot open file")
  exit()
  while True:
    ret, frame = cap.read()
    if not ret:
      print("We cannot receive frame")
      break
  detect_params = model.predict(source=[frame],conf = 0.45, save = False)
  boxes=detect_params[0].boxes
  for i in range(len(boxes)):
    box=boxes[i]
    clsID=int(nox.cls.cpu().numpy()[0])
    connf=box.conf.cpu().numpy()[0]
    bb=box.xyxy.cpu().numpy()[0]
    cv2.rectangle(frame,(int(bb[0]),int(bb[1])),(int(bb[2]),int(bb[3])),detection_color[clsID],(255,0,255),2)
    label = f'{class_list[clsID]} {round(conf*100,2)}%'
    cv2.putText(
        frame,
        label,
        (int(bb[0]), int(bb[1]) - 10),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.5,(255,255,255),2
    )
    clear_output(wait=True)
    imshow(frame)
    cv2.waitKey(1)
  cap.release()
  cv2.destroyAllWindows()

# %%
import cv2
import random
from ultralytics import YOLO
from IPython.display import clear_output
from google.colab.patches import cv2_imshow

# Read class names from file
with open('/content/cock.txt', 'r') as my_file:
    class_list = my_file.read().split('\n')

# Generate random colors
detection_color = []
for _ in range(len(class_list)):
    r = random.randint(0, 255)
    g = random.randint(0, 255)
    b = random.randint(0, 255)
    detection_color.append((r, g, b))

# Load model
model = YOLO('yolov8n.pt')

# Open video file
cap = cv2.VideoCapture('/content/126434-735976920_small.mp4')
if not cap.isOpened():
    print("We cannot open file")
    exit()

# Loop through video frames
while True:
    ret, frame = cap.read()
    if not ret:
        print("Finished processing video.")
        break

    # Perform detection
    detect_params = model.predict(source=[frame], conf=0.45, save=False)
    boxes = detect_params[0].boxes

    for box in boxes:
        clsID = int(box.cls.cpu().numpy()[0])
        conf = box.conf.cpu().numpy()[0]
        bb = box.xyxy.cpu().numpy()[0]

        # Draw rectangle
        cv2.rectangle(frame, (int(bb[0]), int(bb[1])), (int(bb[2]), int(bb[3])),
                      detection_color[clsID], 2)

        # Add label
        label = f'{class_list[clsID]} {round(conf * 100, 2)}%'
        cv2.putText(frame, label, (int(bb[0]), int(bb[1]) - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

    # Display the frame
    clear_output(wait=True)
    cv2_imshow(frame)
    cv2.waitKey(1)

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>
# 0: 384x640 6 persons, 3 cars, 4 motorcycles, 1 truck, 1 fire hydrant, 288.3ms
# Speed: 4.5ms preprocess, 288.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
